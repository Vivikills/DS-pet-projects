# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Intelligence Analysis

# %%
df = pd.read_csv('/kaggle/input/salary-dataset-simple-linear-regression/Salary_dataset.csv')

# %%
df.head(15)

# %%
df.info()

# %%
df.shape

# %%
df.drop(columns = ['Unnamed: 0'], inplace = True)
df.head(15)

# %%
df_years = df['YearsExperience'].value_counts().sort_index()
df_years.head()

# %%
sns.histplot(data = df, x = 'YearsExperience')
plt.title('Distribution on years of experience')

# %%
sns.histplot(data = df, x = 'Salary')
plt.title('Distribution on salary')

# %%
#Сreating a scatterplot with linear regression. Let's use sns.regplot() for this.

sns.regplot(data = df, x = 'YearsExperience', y = 'Salary', line_kws={"color": "red"})
plt.title('Scatterplot with linear regression')

# %%
#Calculation of the Pearson correlation coefficient. It shows the degree of linear correlation between two variables.

per_coeff = df['YearsExperience'].corr(df['Salary'])
print('Pearson correlation coefficient: ', per_coeff)

# %% [markdown]
# Value of the Pearson coefficient indicates that the variables are almost perfectly correlated with each other.

# %% [markdown]
# # Predictive Analysis

# %%
#Calculation the number of non-NA/null values

values = df.count()
values

# %% [markdown]
# There are no missing values in df

# %%
#Importing the necessary elements of the skicit-learn library

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# %%
X = df['YearsExperience']
y = df['Salary']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 11)

X_train = np.array(X_train)
X_train = X_train.reshape(-1,1)
X_test = np.array(X_test)
X_test = X_test.reshape(-1,1)
y_train = np.array(y_train)
y_train = y_train.reshape(-1,1)
y_test = np.array(y_test)
y_test = y_test.reshape(-1,1)

# %%
model = LinearRegression()

model.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print('Squared determination coefficient: ', r2)
print('Mean squared error: ', mse)
